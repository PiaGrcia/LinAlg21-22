# %% [markdown]
# <a href="https://colab.research.google.com/github/PiaGrcia/LinAlg21-22/blob/main/LAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo.png](data:image/png;base64,...)

# %% [markdown]
# # Linear Algebra for ECE

# %% [markdown]
# ## Laboratory Activity 2

# %% [markdown]
# ### VECTORS

# %% [markdown]
# Submitted By:
# Garcia, Ma. Sopia Alyanna D.
#
#
#
# Instructor:
# Engr. Eugene H. Embalzado Jr.
#
#
#
#
# November 9, 2021

# %% [markdown]
# ### OBJECTIVES

# %% [markdown]
# •	This laboratory activity aims to implement the principles and techniques of using Python Language, and how to execute and solve two to three vector using Matplotlib and NumPy.

# %% [markdown]
# ### METHODS

# %% [markdown]
# •	The practices of the activity are to properly execute matplot lib in solving two to three vectors.
#
# •	This laboratory activity shows the different ways on how to input values from matplot lib that will run the program and shows graph as its result.
#
# •	This activity was provided with different techniques and short-cut keys to run the program.
#
# •	 This activity aims to use head to tail method where the given vectors must be align to its head and tails accordingly.
#
# •	This activity is needed to run a numpy as its function and to make it executed well.

# %% [markdown]
# ### Results

# %% [markdown]
# **MATPLOT LIB**

# %%
import numpy as np ## 'np' here is short-hand name of the library (numpy) or a nickname.

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %% [markdown]
# **TWO VECTORS**

# %%
A = [1, 1]
B = [1, 2]
plt.plot(A)
plt.plot(B)
plt.show()

# %%
A = [1, 1]
B = [1, 2]
plt.plot(A, label='A')
plt.plot(B, label='B')
plt.legend()
plt.show()

# %%
A = [1, 1]
B = [1, 2]
plt.scatter(A[0], A[1], label='A')
plt.scatter(B[0], B[1], label='B')
plt.grid()
plt.legend()
plt.show()

# %%
A = [1, -1]
B = [5, -1]
plt.scatter(A[0], A[1], label='A', c='green')
plt.scatter(B[0], B[1], label='B', c='magenta')
plt.grid()
plt.legend()
plt.show()

# %%
A = np.array([1, -1])
B = np.array([1, 5])
plt.title("Resultant Vector\nMagnitude: {}" .format(Magnitude))
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.quiver(0, 0, A[0], A[1], angles='xy', scale_units='xy', scale=1, color='red')
plt.quiver(A[0], A[1], B[0], B[1], angles='xy', scale_units='xy', scale=1, color='green')
R = A + B
plt.quiver(0, 0, R[0], R[1], angles='xy', scale_units='xy', scale=1, color='blue')
plt.grid()
plt.show()
print('R is', R)
Magnitude = np.sqrt(np.sum(R**2))
print('Magnitude is', Magnitude)
Slope = R[1]/R[0]
print('Slope is', Slope)
Angle =  (np.arctan(Slope))*(180/np.pi)
print('Angle is', Angle)
# Out:
# R is [2 4]
# Magnitude is 4.47213595499958
# Slope is 2.0
# Angle is 63.43494882292201

# %% [markdown]
# **THREE VECTORS**

# %%
A = [2, -1]
B = [1, 1]
C = [1, 1]
plt.plot(A)
plt.plot(B)
plt.plot(C)
plt.show()

# %%
A = [2, -1]
B = [1, 1]
C = [1, 1]
plt.plot(A, label='A')
plt.plot(B, label='B')
plt.plot(C, label='C')
plt.legend()
plt.show()

# %%
A = [2, -1]
B = [1, 1]
C = [1, 1]
plt.scatter(A[0], A[1], label='A')
plt.scatter(B[0], B[1], label='B')
plt.scatter(C[0], C[1], label='C')
plt.grid()
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
A = [2, -1]
B = [1, 1]
C = [1, 1]
plt.title("Resultant Vector\nMagnitude:{}" .format(Magnitude))
plt.xlim(-4, 4)
plt.ylim(-4, 4)
plt.quiver(0, 0, A[0], A[1], angles='xy', scale_units='xy', scale=1, color='green')
plt.quiver(A[0], A[1], B[0], B[1], angles='xy', scale_units='xy', scale=1, color='blue')
plt.quiver(B[0], B[1], A[0], A[1], angles='xy', scale_units='xy', scale=1, color='violet')
plt.quiver(C[0], C[1], angles='xy', scale_units='xy', scale=1, color='green')
R = A + B + C
plt.quiver(0, 0, R[0], R[1], angles='xy', scale_units='xy', scale=1, color='black')
plt.grid()
plt.show()
print(R)
Magnitude = np.sqrt(np.sum(R*2))
print(Magnitude)
Slope = R[1]/R[0]
print(Slope)
Angle = (np.arctan(Slope))*(180/np.pi)
print(Angle)
# Out:
# [2, -1, 1, 1, 1, 1]
# 3.1622776601683795
# -0.5
# -26.56505117707799

# %% [markdown]
# ### Conclusion

# %% [markdown]
# After this laboratory activity, I have discovered another python library where it shows graph and execute vector quantities. Matplot lib is a multi-platform data visualization library built with NumPy arrays, it has the ability to operate many systems and graphics. That is why in this laboratory activity, I enhance my knowledge and skills in Python with the addition of Matplotlib in solving for vectors, either two or more vectors.
#
# This activity challenges my skills in physics and programming because in solving for three vectors, I need to find that value for A, B, and C that can create a graph which show the 3 vectors are connected with heads and tails. I explore different values for x and y that can give me an exact graph of the vector.
#
# I am amazed that Python has this kind of library that can execute codes, solve operations, shows graphs, and more. With some errors I encountered in this activity, I will improve and enhance my skills using Python, using Numpy and Matplotlib as the library used in this past activities.
