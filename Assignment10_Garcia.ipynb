# %% [markdown]
# <a href="https://colab.research.google.com/github/PiaGrcia/LinAlg21-22/blob/main/Assignment10_Garcia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo.png](data:image/png;base64,...)

# %% [markdown]
# # Linear Algebra for ECE

# %% [markdown]
# ## Laboratory Activity 10

# %% [markdown]
# ### Linear Combination and Vector Spaces

# %% [markdown]
# Submitted By:
# Garcia, Ma. Sopia Alyanna D.
#
#
#
# Instructor:
# Engr. Eugene H. Embalzado Jr.
#
#
#
#
# November 14, 2021

# %% [markdown]
# ### OBJECTIVES:

# %% [markdown]
# •	This laboratory activity aims to implement the principles and techniques of using Python Language, and how to execute and solve a linear combination and vector space using Numpy and Matplotlib as its library resources.

# %% [markdown]
# ### METHODS:

# %% [markdown]
# •	The practices of the activity are to properly execute matplot lib in solving vector spaces.
#
# •	This laboratory activity shows the different ways on how to input values from matplot lib that will run the program and shows graph as its result.
#
# •	This activity was provided with different techniques and short-cut keys to run the program.
#
# •	 This activity aims to execute resources library such as Numpy and Matplotlib to run the vector spaces and have a graph as its ourtput.
#
# •	This activity is to know how to use Google Colab to run and execute a program about linear combination and vector spaces.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Linear Combinations Activity

# %% [markdown]
# $$ X = \begin{bmatrix} 2\\5 \\\end{bmatrix} , Y = \begin{bmatrix} 7\\9 \\\end{bmatrix} $$

# %%
vectX = np.array([2,5])
vectY = np.array([7,9])

# %% [markdown]
# ### Span of single vectors

# %% [markdown]
# $$X = c\cdot \begin{bmatrix} 2\\5 \\\end{bmatrix} $$

# %%
c = np.arange(-10,10,0.125)

plt.scatter(c*vectX[0],c*vectX[1])

plt.xlim(-10,10)
plt.ylim(-10,10)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# $$Y = c\cdot \begin{bmatrix} 7\\9 \\\end{bmatrix} $$

# %%
c = np.arange(-15,15,0.5)

plt.scatter(c*vectY[0],c*vectY[1])

plt.xlim(-20,20)
plt.ylim(-20,20)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ### Span of a linear combination of vectors

# %% [markdown]
# $$S = \begin{Bmatrix} c_1 \cdot\begin{bmatrix} 1\\0 \\\end{bmatrix},
# c_2 \cdot \begin{bmatrix} 1\\-1 \\\end{bmatrix}\end{Bmatrix} $$

# %%
vectA = np.array([1,0])
vectB = np.array([1,-1])

R = np.arange(-10,10,1)

c1, c2 = np.meshgrid(R,R)


vectR = vectA + vectB
spanRx = c1*vectA[0] + c2*vectB[0]
spanRy = c1*vectA[1] + c2*vectB[1]
 #plt.scatter(R*vectA[0],R*vectA[1])
 #plt.scatter(R*vectB[0],R*vectB[1])
plt.scatter(spanRx,spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %%
vectP = np.array([2,1])
vectQ = np.array([4,3])

R = np.arange(-10,10,1)

c1, c2 = np.meshgrid(R,R)


vectR = vectP + vectQ
spanRx = c1*vectP[0] + c2*vectQ[0]
spanRy = c1*vectP[1] + c2*vectQ[1]
 #plt.scatter(R*vectP[0],R*vectP[1])
 #plt.scatter(R*vectQ[0],R*vectQ[1])
plt.scatter(spanRx,spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ## **TASK 1**

# %% [markdown]
# Try different linear combinations using different scalar values. In your methodology discuss the different functions that you have used, the  linear equation and vector form of the linear combination, and the flowchart for declaring and displaying linear combinations. Please make sure that your flowchart has only few words and not putting the entire code as it is bad practice. In your results, display and discuss the linear combination visualization you made. You should use the cells below for displaying the equation markdows using LaTeX and your code.

# %% [markdown]
# **EXAMPLE 1**

# %% [markdown]
# Linear Form

# %% [markdown]
# $$Pia = \begin{bmatrix}M = \begin{bmatrix} 3\\-2 \\\end{bmatrix} , J = \begin{bmatrix} 4\\6 \\\end{bmatrix} \\\end{bmatrix}$$

# %% [markdown]
# Vector Form

# %% [markdown]
# $$Pia = \begin{Bmatrix} c_1 \cdot\begin{bmatrix} 3\\-2 \\\end{bmatrix},
# c_2 \cdot \begin{bmatrix} 4\\6 \\\end{bmatrix}\end{Bmatrix} $$

# %% [markdown]
# **EXAMPLE 2**

# %% [markdown]
# Linear Form

# %% [markdown]
# $$Pia = \begin{bmatrix}D = \begin{bmatrix} 5\\8 \\\end{bmatrix} , J = \begin{bmatrix} -3\\7 \\\end{bmatrix} \\\end{bmatrix}$$

# %% [markdown]
# Vector Form

# %% [markdown]
# $$Pia = \begin{Bmatrix} c_1 \cdot\begin{bmatrix} 5\\8 \\\end{bmatrix},
# c_2 \cdot \begin{bmatrix} -3\\7 \\\end{bmatrix}\end{Bmatrix} $$

# %% [markdown]
# ### **SPAN OF SINGLE VECTORS**

# %% [markdown]
# ### EXAMPLE 1

# %% [markdown]
# $$Pia = \begin{bmatrix}M = \begin{bmatrix} 3\\-2 \\\end{bmatrix} , J = \begin{bmatrix} 4\\6 \\\end{bmatrix} \\\end{bmatrix}$$

# %%
vectM = np.array([3, -2])
vectJ = np.array([4, 6])

# %% [markdown]
# $$M = c\cdot \begin{bmatrix} 3\\-2 \\\end{bmatrix} $$

# %%
c = np.arange(-8,8,0.80)

plt.scatter(c*vectM[0],c*vectM[1])

plt.xlim(-15,15)
plt.ylim(-15,15)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# $$J = c\cdot \begin{bmatrix} 4\\6 \\\end{bmatrix} $$

# %%
c = np.arange(-8,8,0.80)

plt.scatter(c*vectJ[0],c*vectJ[1])

plt.xlim(-15,15)
plt.ylim(-15,15)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ### EXAMPLE 2

# %% [markdown]
# $$Pia = \begin{bmatrix}D = \begin{bmatrix} 5\\8 \\\end{bmatrix} , J = \begin{bmatrix} -3\\7 \\\end{bmatrix} \\\end{bmatrix}$$

# %%
vectD = np.array([5, 8])
vectS = np.array([-3, 7])

# %% [markdown]
# $$D = c\cdot \begin{bmatrix} 5\\8 \\\end{bmatrix} $$

# %%
c = np.arange(-12,12,1.25)

plt.scatter(c*vectD[0],c*vectD[1])

plt.xlim(-30,30)
plt.ylim(-30,30)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# $$S = c\cdot \begin{bmatrix} -3\\7 \\\end{bmatrix} $$

# %%
c = np.arange(-12,12,1.25)

plt.scatter(c*vectS[0],c*vectS[1])

plt.xlim(-30,30)
plt.ylim(-30,30)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ### SPAN OF LINEAR COMBINATION OF VECTORS

# %% [markdown]
# ### EXAMPLE 1

# %% [markdown]
# $$Pia = \begin{Bmatrix} c_1 \cdot\begin{bmatrix} 3\\-2 \\\end{bmatrix},
# c_2 \cdot \begin{bmatrix} 4\\6 \\\end{bmatrix}\end{Bmatrix} $$

# %%
vectM = np.array([3,-2])
vectJ = np.array([4,6])

R = np.arange(-15,15,1.50)

c1, c2 = np.meshgrid(R,R)


vectR = vectM + vectJ
spanRx = c1*vectM[0] + c2*vectJ[0]
spanRy = c1*vectM[1] + c2*vectJ[1]
 #plt.scatter(R*vectM[0],R*vectM[1])
 #plt.scatter(R*vectJ[0],R*vectJ[1])
plt.scatter(spanRx,spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ### EXAMPLE 2

# %% [markdown]
# $$Pia = \begin{Bmatrix} c_1 \cdot\begin{bmatrix} 5\\8 \\\end{bmatrix},
# c_2 \cdot \begin{bmatrix} -3\\7 \\\end{bmatrix}\end{Bmatrix} $$

# %%
vectD = np.array([5, 8])
vectS = np.array([-3, 7])

R = np.arange(-50,50,2)

c1, c2 = np.meshgrid(R,R)


vectR = vectD + vectS
spanRx = c1*vectD[0] + c2*vectS[0]
spanRy = c1*vectD[1] + c2*vectS[1]
 #plt.scatter(R*vectD[0],R*vectD[1])
 #plt.scatter(R*vectS[0],R*vectS[1])
plt.scatter(spanRx,spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ### FLOWCHART

# %% [markdown]
# **SPAN OF SINGLE VECTORS**

# %% [markdown]
# ### EXAMPLE 1

# %% [markdown]
# ![Flowchart.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Flowchart (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### EXAMPLE 2

# %% [markdown]
# ![Flowchart (2).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Flowchart (3).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **SPAN OF LINEAR COMBINATION OF VECTORS**

# %% [markdown]
# ### EXAMPLE 1

# %% [markdown]
# ![Flowchart (5).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### EXAMPLE 2

# %% [markdown]
# ![Flowchart (6).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### CONCLUSION:

# %% [markdown]
# For your conclusion synthesize the concept and application of the laboratory. Briefly discuss what you have learn and achieved in this activity. At the end of your conclusion try to answer the question : "How can you apply the concept of linear combination in engineering or real-life situations?".

# %% [markdown]
# On this laboratory activity, the use of python as the language is useful when solving for linear combinations of vector spaces. In the span of single vectors, it multiplies to all scalar quantities given. Like in the example 1 and 2, the vector span is the combination of all set of vectors. No matter how the graph stretches or shrinks, it will always be on the same line because the direction is not changing its value. So in the output of every examples are only focus on one direction, either to positive x axis or negative x axis. While for span of linear combination of vectors, it comprises of all the vector quantity given. If one vector is equal to the sum of scalar multiples, the vector is called linear combination. It combines all vectors to form a linear combination of vectors, that why the two examples and its graph are like a square or rectangle pointed to the positive x-axis.
#
# I have learned that vectors has both magnitude and direction. In order to know where the point or line is going, there should be a direction, whether to positive or negative x-axis. In this activity, I have discovered that using Python in Google Colab, I can compute and solve vectors span and linear combination of vector using Python library resources such as Numpy and Matplotlib. There is such a code or function that can execute the vectors and solve it with the use of graph as its output.
#
# I can apply this concept of linear combination in real-life by budgeting allowance and savings. I can use this knowledge in solving for how much is my allowance to how much is my total savings during a month or week. With this I think I can solve the budget I have for the rest of the month by adding or combing the allowance I received every week to the savings I have accumulated in the past weeks and months. With the budget I have, I can earn enough money that I can use for buying my needs in life, at school, and at home.
